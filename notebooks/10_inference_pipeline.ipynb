# %%
from src.inference import (
    Predictor
)

# %%
predictor = (
    Predictor()
)

# %%
result = predictor.predict(

    "../data/real_world/audio/clock_alarm/alarm_1.wav"

)

result

# %%
from pathlib import Path

# %%
ROOT = Path(
    "../data/real_world/audio"
)

for folder in ROOT.iterdir():

    for file in folder.glob(
        "*.wav"
    ):

        print()

        print(
            file.name
        )

        print(

            predictor.predict(
                file
            )
        )
